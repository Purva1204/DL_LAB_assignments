# %% [markdown]
# <a href="https://colab.research.google.com/github/Purva1204/DL_LAB_assignments/blob/main/assignment-1/Assignment_1_TensorFlow_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q tensorflow

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

print("TensorFlow version:", tf.__version__)
print("Keras version:", keras.__version__)
# Out:
# TensorFlow version: 2.20.0
# Keras version: 3.13.2

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

print("Training data shape:", x_train.shape)
print("Training labels shape:", y_train.shape)
print("Testing data shape:", x_test.shape)
print("Testing labels shape:", y_test.shape)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training data shape: (60000, 28, 28)
# Training labels shape: (60000,)
# Testing data shape: (10000, 28, 28)
# Testing labels shape: (10000,)

# %%
print("Data type:", x_train.dtype)
print("Pixel value range:", x_train.min(), "to", x_train.max())


x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

print("After normalization:")
print("Pixel value range:", x_train.min(), "to", x_train.max())
# Out:
# Data type: uint8
# Pixel value range: 0 to 255
# After normalization:
# Pixel value range: 0.0 to 1.0

# %%
print("Training samples:", len(x_train))
print("Testing samples:", len(x_test))

print("Training set shape:", x_train.shape)
print("Test set shape:", x_test.shape)

# %%
plt.figure(figsize=(10, 4))

for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_train[i], cmap="gray")
    plt.title(f"Label: {y_train[i]}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
unique, counts = np.unique(y_train, return_counts=True)

plt.figure(figsize=(8, 5))
plt.bar(unique, counts)
plt.xlabel("Digit")
plt.ylabel("Number of samples")
plt.title("MNIST Training Dataset Distribution")
plt.xticks(unique)
plt.show()

# %%
print("Final training shape:", x_train.shape)
print("Final testing shape:", x_test.shape)
print("Minimum pixel value:", x_train.min())
print("Maximum pixel value:", x_train.max())
# Out:
# Final training shape: (60000, 28, 28)
# Final testing shape: (10000, 28, 28)
# Minimum pixel value: 0.0
# Maximum pixel value: 1.0

# %%
print("Data preprocessing completed successfully!")
print("✓ TensorFlow/Keras installed and configured")
print("✓ MNIST dataset loaded")
print("✓ Data preprocessing performed")
print("✓ Pixel values normalized to range 0-1")
print("✓ Training and testing sets prepared")
print("✓ Data visualized")
# Out:
# Data preprocessing completed successfully!
# ✓ TensorFlow/Keras installed and configured
# ✓ MNIST dataset loaded
# ✓ Data preprocessing performed
# ✓ Pixel values normalized to range 0-1
# ✓ Training and testing sets prepared
# ✓ Data visualized
